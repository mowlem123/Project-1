# %% [markdown]
# # Michelin Star Restuarants for New York City and San Francisco

# %% [markdown]
# ## Imports and Reading in CSVs

# %%
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path
from dotenv import load_dotenv
from panel.interact import interact
from panel import widgets

# %%
file_path = Path("Data/one-star-michelin-restaurants.csv")
one_star_data = pd.read_csv(file_path, index_col='year')
one_star_data.head()
# Out:
#                name   latitude  longitude            city   region zipCode  \
# year
# 2019   Kilian Stuba  47.348580   10.17114  Kleinwalsertal  Austria   87568
# 2019  Pfefferschiff  47.837870   13.07917        Hallwang  Austria    5300
# 2019      Esszimmer  47.806850   13.03409        Salzburg  Austria    5020
# 2019     Carpe Diem  47.800010   13.04006        Salzburg  Austria    5020
# 2019         Edvard  48.216503   16.36852            Wien  Austria    1010
#
#               cuisine  price  \
# year
# 2019         Creative  $$$$$
# 2019  Classic cuisine  $$$$$
# 2019         Creative  $$$$$
# 2019   Market cuisine  $$$$$
# 2019   Modern cuisine   $$$$
#
#                                                     url
# year
# 2019  https://guide.michelin.com/at/en/vorarlberg/kl...
# 2019  https://guide.michelin.com/at/en/salzburg-regi...
# 2019  https://guide.michelin.com/at/en/salzburg-regi...
# 2019  https://guide.michelin.com/at/en/salzburg-regi...
# 2019  https://guide.michelin.com/at/en/vienna/wien/r...

# %%
file_path = Path("Data/two-stars-michelin-restaurants.csv")
two_star_data = pd.read_csv(file_path, index_col= 'year')
two_star_data.head()
# Out:
#                                   name  latitude  longitude      city  \
# year
# 2019                  SENNS.Restaurant  47.83636   13.06389  Salzburg
# 2019                            Ikarus  47.79536   13.00695  Salzburg
# 2019                       Mraz & Sohn  48.23129   16.37637      Wien
# 2019               Konstantin Filippou  48.21056   16.37996      Wien
# 2019  Silvio Nickol Gourmet Restaurant  48.20558   16.37693      Wien
#
#        region zipCode         cuisine  price  \
# year
# 2019  Austria    5020        Creative  $$$$$
# 2019  Austria    5020        Creative  $$$$$
# 2019  Austria    1200        Creative  $$$$$
# 2019  Austria    1010  Modern cuisine  $$$$$
# 2019  Austria    1010  Modern cuisine  $$$$$
#
#                                                     url
# year
# 2019  https://guide.michelin.com/at/en/salzburg-regi...
# 2019  https://guide.michelin.com/at/en/salzburg-regi...
# 2019  https://guide.michelin.com/at/en/vienna/wien/r...
# 2019  https://guide.michelin.com/at/en/vienna/wien/r...
# 2019  https://guide.michelin.com/at/en/vienna/wien/r...

# %%
file_path = Path("Data/three-stars-michelin-restaurants.csv")
three_star_data = pd.read_csv(file_path, index_col= 'year')
three_star_data.head()
# Out:
#                name  latitude  longitude                 city      region  \
# year
# 2019         Amador  48.25406   16.35915                 Wien     Austria
# 2019        Manresa  37.22761 -121.98071  South San Francisco  California
# 2019           Benu  37.78521 -122.39876        San Francisco  California
# 2019         Quince  37.79762 -122.40337        San Francisco  California
# 2019  Atelier Crenn  37.79835 -122.43586        San Francisco  California
#
#      zipCode       cuisine  price  \
# year
# 2019    1190      Creative  $$$$$
# 2019   95030  Contemporary   $$$$
# 2019   94105         Asian   $$$$
# 2019   94133  Contemporary   $$$$
# 2019   94123  Contemporary   $$$$
#
#                                                     url
# year
# 2019  https://guide.michelin.com/at/en/vienna/wien/r...
# 2019  https://guide.michelin.com/us/en/california/so...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...

# %% [markdown]
# ## NYC One Star Information

# %%
nyc_one_star_data = one_star_data.loc[one_star_data['city'] == 'New York']
nyc_one_star_data.head()
# Out:
#                            name   latitude  longitude      city  \
# year
# 2019                  Del Posto  40.743270  -74.00770  New York
# 2019  Le Grill de Joël Robuchon  40.742897  -74.00770  New York
# 2019                   L'Appart  40.711903  -74.01544  New York
# 2019                      Okuda  40.743793  -74.00633  New York
# 2019                     Wallsé  40.735380  -74.00814  New York
#
#              region zipCode   cuisine price  \
# year
# 2019  New York City   10011   Italian  $$$$
# 2019  New York City     NaN    French  $$$$
# 2019  New York City   10281    French  $$$$
# 2019  New York City     NaN  Japanese  $$$$
# 2019  New York City   10014  Austrian  $$$$
#
#                                                     url
# year
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...

# %%
nyc_one_df = nyc_one_star_data.drop(['latitude', 'longitude', 'zipCode', 'url', 'region'], axis=1)
nyc_one_df = nyc_one_df.set_index('city')
nyc_one_df.head()
# Out:
#                                name   cuisine price
# city
# New York                  Del Posto   Italian  $$$$
# New York  Le Grill de Joël Robuchon    French  $$$$
# New York                   L'Appart    French  $$$$
# New York                      Okuda  Japanese  $$$$
# New York                     Wallsé  Austrian  $$$$

# %%
nyc_one_df['cuisine'].value_counts()
# Out:
# Japanese         16
# Contemporary      9
# Italian           4
# American          4
# French            4
# Mexican           3
# Korean            3
# Mediterranean     2
# Spanish           1
# Fusion            1
# Scandinavian      1
# Chinese           1
# Vegetarian        1
# Thai              1
# Indian            1
# Seafood           1
# Austrian          1
# Steakhouse        1
# Name: cuisine, dtype: int64

# %%
nyc_one_bar = nyc_one_df.plot.bar(x = 'cuisine', y =)
nyc_one_bar
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28684/2487484038.py in <module>
# ----> 1 nyc_one_bar = nyc_one_df.plot.bar(x = 'cuisine', y = [0])
#       2 nyc_one_bar
#
# ~\Anaconda\envs\pyvizenv\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1128         other axis represents a measured value.
#    1129         """
# -> 1130         return self(kind="bar", x=x, y=y, **kwargs)
#    1131
#    1132     @Appender(
#
# ~\Anaconda\envs\pyvizenv\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\Anaconda\envs\pyvizenv\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\Anaconda\envs\pyvizenv\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     284     def generate(self):
#     285         self._args_adjust()
# --> 286         self._compute_plot_data()
#     287         self._setup_subplots()
#     288         self._make_plot()
#
# ~\Anaconda\envs\pyvizenv\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     451         # no non-numeric frames or series allowed
#     452         if is_empty:
# --> 453             raise TypeError("no numeric data to plot")
#     454
#     455         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
nyc_one_df.isnull().sum()
# Out:
# name       0
# cuisine    0
# price      0
# dtype: int64

# %% [markdown]
# ### Location Data

# %%
nyc_one_loc = nyc_one_star_data.drop(['cuisine', 'url', 'price', 'zipCode', 'region'], axis=1)
nyc_one_loc = nyc_one_loc.set_index('city')
nyc_one_loc.head()
# Out:
#                                name   latitude  longitude
# city
# New York                  Del Posto  40.743270  -74.00770
# New York  Le Grill de Joël Robuchon  40.742897  -74.00770
# New York                   L'Appart  40.711903  -74.01544
# New York                      Okuda  40.743793  -74.00633
# New York                     Wallsé  40.735380  -74.00814

# %%
nyc_one_loc.isnull().sum()
# Out:
# name         0
# latitude     0
# longitude    0
# dtype: int64

# %% [markdown]
# ## NYC Two Star Information

# %%
nyc_two_star_data = two_star_data.loc[two_star_data['city'] == 'New York']
nyc_two_star_data.head()
# Out:
#                             name   latitude  longitude      city  \
# year
# 2019  L'Atelier de Joël Robuchon  40.742905  -74.00769  New York
# 2019                     Jungsik  40.718685  -74.00911  New York
# 2019                       Atera  40.716797  -74.00565  New York
# 2019                Jean-Georges  40.769070  -73.98155  New York
# 2019                       Marea  40.767490  -73.98114  New York
#
#              region zipCode       cuisine price  \
# year
# 2019  New York City     NaN        French  $$$$
# 2019  New York City   10013        Korean  $$$$
# 2019  New York City   10013  Contemporary  $$$$
# 2019  New York City   10023  Contemporary  $$$$
# 2019  New York City   10019       Seafood  $$$$
#
#                                                     url
# year
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...

# %%
nyc_two_df = nyc_two_star_data.drop(['latitude', 'longitude', 'zipCode', 'url', 'region'], axis=1)
nyc_two_df = nyc_two_df.set_index('city')
nyc_two_df.head()
# Out:
#                                 name       cuisine price
# city
# New York  L'Atelier de Joël Robuchon        French  $$$$
# New York                     Jungsik        Korean  $$$$
# New York                       Atera  Contemporary  $$$$
# New York                Jean-Georges  Contemporary  $$$$
# New York                       Marea       Seafood  $$$$

# %% [markdown]
# ### Location Data

# %%
nyc_two_loc = nyc_two_star_data.drop(['cuisine', 'url', 'price', 'zipCode', 'region'], axis=1)
nyc_two_loc = nyc_two_loc.set_index('city')
nyc_two_loc.head()
# Out:
#                                 name   latitude  longitude
# city
# New York  L'Atelier de Joël Robuchon  40.742905  -74.00769
# New York                     Jungsik  40.718685  -74.00911
# New York                       Atera  40.716797  -74.00565
# New York                Jean-Georges  40.769070  -73.98155
# New York                       Marea  40.767490  -73.98114

# %%
nyc_two_loc.isnull().sum()
# Out:
# name         0
# latitude     0
# longitude    0
# dtype: int64

# %% [markdown]
# ## NYC Three Star Information

# %%
nyc_three_star_data = three_star_data.loc[three_star_data['city'] == 'New York']
nyc_three_star_data.head()
# Out:
#                                name  latitude  longitude      city  \
# year
# 2019                           Masa  40.76855  -73.98335  New York
# 2019                         Per Se  40.76828  -73.98292  New York
# 2019                   Le Bernardin  40.76177  -73.98223  New York
# 2019            Eleven Madison Park  40.74170  -73.98712  New York
# 2019  Chef's Table at Brooklyn Fare  40.68872  -73.98581  New York
#
#              region zipCode       cuisine price  \
# year
# 2019  New York City   10019      Japanese  $$$$
# 2019  New York City   10019  Contemporary  $$$$
# 2019  New York City   10019       Seafood  $$$$
# 2019  New York City   10010  Contemporary  $$$$
# 2019  New York City   10018  Contemporary  $$$$
#
#                                                     url
# year
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...

# %%
nyc_three_df = nyc_three_star_data.drop(['latitude', 'longitude', 'zipCode', 'url', 'region'], axis=1)
nyc_three_df = nyc_three_df.set_index('city')
nyc_three_df.head()
# Out:
#                                    name       cuisine price
# city
# New York                           Masa      Japanese  $$$$
# New York                         Per Se  Contemporary  $$$$
# New York                   Le Bernardin       Seafood  $$$$
# New York            Eleven Madison Park  Contemporary  $$$$
# New York  Chef's Table at Brooklyn Fare  Contemporary  $$$$

# %% [markdown]
# ### Location Data

# %%
nyc_three_loc = nyc_three_star_data.drop(['cuisine', 'url', 'price', 'zipCode', 'region'], axis=1)
nyc_three_loc = nyc_three_loc.set_index('city')
nyc_three_loc.head()
# Out:
#                                    name  latitude  longitude
# city
# New York                           Masa  40.76855  -73.98335
# New York                         Per Se  40.76828  -73.98292
# New York                   Le Bernardin  40.76177  -73.98223
# New York            Eleven Madison Park  40.74170  -73.98712
# New York  Chef's Table at Brooklyn Fare  40.68872  -73.98581

# %% [markdown]
# ## SF One Star Information

# %%
sf_one_star_data = one_star_data.loc[one_star_data['city'] == 'San Francisco']
sf_one_star_data.head()
# Out:
#                  name   latitude   longitude           city      region  \
# year
# 2019           Madera  37.420140 -122.211510  San Francisco  California
# 2019  The Village Pub  37.428970 -122.251780  San Francisco  California
# 2019         Wakuriya  37.521140 -122.336600  San Francisco  California
# 2019  Sushi Yoshizumi  37.565075 -122.321100  San Francisco  California
# 2019             Rasa  37.577522 -122.345985  San Francisco  California
#
#      zipCode       cuisine price  \
# year
# 2019   94025  Contemporary   $$$
# 2019   94062  Contemporary   $$$
# 2019   94402      Japanese  $$$$
# 2019   94401      Japanese  $$$$
# 2019   94010        Indian    $$
#
#                                                     url
# year
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...

# %%
sf_one_df = sf_one_star_data.drop(['latitude', 'longitude', 'zipCode', 'url', 'region'], axis=1)
sf_one_df = sf_one_df.set_index('city')
sf_one_df.head()
# Out:
#                           name       cuisine price
# city
# San Francisco           Madera  Contemporary   $$$
# San Francisco  The Village Pub  Contemporary   $$$
# San Francisco         Wakuriya      Japanese  $$$$
# San Francisco  Sushi Yoshizumi      Japanese  $$$$
# San Francisco             Rasa        Indian    $$

# %% [markdown]
# ### Location Data

# %%
sf_one_loc = sf_one_star_data.drop(['cuisine', 'url', 'price', 'zipCode', 'region'], axis=1)
sf_one_loc = sf_one_loc.set_index('city')
sf_one_loc.head()
# Out:
#                           name   latitude   longitude
# city
# San Francisco           Madera  37.420140 -122.211510
# San Francisco  The Village Pub  37.428970 -122.251780
# San Francisco         Wakuriya  37.521140 -122.336600
# San Francisco  Sushi Yoshizumi  37.565075 -122.321100
# San Francisco             Rasa  37.577522 -122.345985

# %% [markdown]
# ## SF Two Star Information

# %%
sf_two_star_data = two_star_data.loc[two_star_data['city'] == 'San Francisco']
sf_two_star_data.head()
# Out:
#                name   latitude   longitude           city      region zipCode  \
# year
# 2019         Commis  37.824760 -122.255050  San Francisco  California   94601
# 2019    Californios  37.755550 -122.417145  San Francisco  California   94110
# 2019      Lazy Bear  37.760204 -122.419690  San Francisco  California   94110
# 2019         Saison  37.763270 -122.415430  San Francisco  California   94107
# 2019  Campton Place  37.789230 -122.406650  San Francisco  California   94108
#
#            cuisine price                                                url
# year
# 2019  Contemporary  $$$$  https://guide.michelin.com/us/en/california/sa...
# 2019       Mexican  $$$$  https://guide.michelin.com/us/en/california/sa...
# 2019  Contemporary  $$$$  https://guide.michelin.com/us/en/california/sa...
# 2019   Californian  $$$$  https://guide.michelin.com/us/en/california/sa...
# 2019        Indian  $$$$  https://guide.michelin.com/us/en/california/sa...

# %%
sf_two_df = sf_two_star_data.drop(['latitude', 'longitude', 'zipCode', 'url', 'region'], axis=1)
sf_two_df = sf_two_df.set_index('city')
sf_one_df.head()
# Out:
#                           name       cuisine price
# city
# San Francisco           Madera  Contemporary   $$$
# San Francisco  The Village Pub  Contemporary   $$$
# San Francisco         Wakuriya      Japanese  $$$$
# San Francisco  Sushi Yoshizumi      Japanese  $$$$
# San Francisco             Rasa        Indian    $$

# %% [markdown]
# ### Location Data

# %%
sf_two_loc = sf_two_star_data.drop(['cuisine', 'url', 'price', 'zipCode', 'region'], axis=1)
sf_two_loc = sf_two_loc.set_index('city')
sf_two_loc.head()
# Out:
#                         name   latitude   longitude
# city
# San Francisco         Commis  37.824760 -122.255050
# San Francisco    Californios  37.755550 -122.417145
# San Francisco      Lazy Bear  37.760204 -122.419690
# San Francisco         Saison  37.763270 -122.415430
# San Francisco  Campton Place  37.789230 -122.406650

# %% [markdown]
# ## SF Three Star Information

# %%
sf_three_star_data = three_star_data.loc[three_star_data['city'] == 'San Francisco']
sf_three_star_data.head()
# Out:
#                              name  latitude  longitude           city  \
# year
# 2019                         Benu  37.78521 -122.39876  San Francisco
# 2019                       Quince  37.79762 -122.40337  San Francisco
# 2019                Atelier Crenn  37.79835 -122.43586  San Francisco
# 2019           The French Laundry  38.40443 -122.36474  San Francisco
# 2019  The Restaurant at Meadowood  38.52025 -122.46479  San Francisco
#
#           region zipCode       cuisine price  \
# year
# 2019  California   94105         Asian  $$$$
# 2019  California   94133  Contemporary  $$$$
# 2019  California   94123  Contemporary  $$$$
# 2019  California   94599  Contemporary  $$$$
# 2019  California   94574  Contemporary  $$$$
#
#                                                     url
# year
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...

# %%
sf_three_df = sf_three_star_data.drop(['latitude', 'longitude', 'zipCode', 'url', 'region'], axis=1)
sf_three_df = sf_three_df.set_index('city')
sf_three_df.head()
# Out:
#                                       name       cuisine price
# city
# San Francisco                         Benu         Asian  $$$$
# San Francisco                       Quince  Contemporary  $$$$
# San Francisco                Atelier Crenn  Contemporary  $$$$
# San Francisco           The French Laundry  Contemporary  $$$$
# San Francisco  The Restaurant at Meadowood  Contemporary  $$$$

# %% [markdown]
# ### Location Data

# %%
sf_three_loc = sf_three_star_data.drop(['cuisine', 'url', 'price', 'zipCode', 'region'], axis=1)
sf_three_loc = sf_three_loc.set_index('city')
sf_three_loc.head()
# Out:
#                                       name  latitude  longitude
# city
# San Francisco                         Benu  37.78521 -122.39876
# San Francisco                       Quince  37.79762 -122.40337
# San Francisco                Atelier Crenn  37.79835 -122.43586
# San Francisco           The French Laundry  38.40443 -122.36474
# San Francisco  The Restaurant at Meadowood  38.52025 -122.46479
