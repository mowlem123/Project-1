# %% [markdown]
# ## Imports and Reading in CSVs

# %%
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
from pathlib import Path
from dotenv import load_dotenv

# %%
file_path = Path("Data/one-star-michelin-restaurants.csv")
one_star_data = pd.read_csv(file_path, index_col='year')
one_star_data.head()
# Out:
#                name   latitude  longitude            city   region zipCode  \
# year
# 2019   Kilian Stuba  47.348580   10.17114  Kleinwalsertal  Austria   87568
# 2019  Pfefferschiff  47.837870   13.07917        Hallwang  Austria    5300
# 2019      Esszimmer  47.806850   13.03409        Salzburg  Austria    5020
# 2019     Carpe Diem  47.800010   13.04006        Salzburg  Austria    5020
# 2019         Edvard  48.216503   16.36852            Wien  Austria    1010
#
#               cuisine  price  \
# year
# 2019         Creative    5.0
# 2019  Classic cuisine    5.0
# 2019         Creative    5.0
# 2019   Market cuisine    5.0
# 2019   Modern cuisine    4.0
#
#                                                     url
# year
# 2019  https://guide.michelin.com/at/en/vorarlberg/kl...
# 2019  https://guide.michelin.com/at/en/salzburg-regi...
# 2019  https://guide.michelin.com/at/en/salzburg-regi...
# 2019  https://guide.michelin.com/at/en/salzburg-regi...
# 2019  https://guide.michelin.com/at/en/vienna/wien/r...

# %%
file_path = Path("Data/two-stars-michelin-restaurants.csv")
two_star_data = pd.read_csv(file_path, index_col= 'year')
two_star_data.head()
# Out:
#                                   name  latitude  longitude      city  \
# year
# 2019                  SENNS.Restaurant  47.83636   13.06389  Salzburg
# 2019                            Ikarus  47.79536   13.00695  Salzburg
# 2019                       Mraz & Sohn  48.23129   16.37637      Wien
# 2019               Konstantin Filippou  48.21056   16.37996      Wien
# 2019  Silvio Nickol Gourmet Restaurant  48.20558   16.37693      Wien
#
#        region zipCode         cuisine  price  \
# year
# 2019  Austria    5020        Creative    5.0
# 2019  Austria    5020        Creative    5.0
# 2019  Austria    1200        Creative    5.0
# 2019  Austria    1010  Modern cuisine    5.0
# 2019  Austria    1010  Modern cuisine    5.0
#
#                                                     url
# year
# 2019  https://guide.michelin.com/at/en/salzburg-regi...
# 2019  https://guide.michelin.com/at/en/salzburg-regi...
# 2019  https://guide.michelin.com/at/en/vienna/wien/r...
# 2019  https://guide.michelin.com/at/en/vienna/wien/r...
# 2019  https://guide.michelin.com/at/en/vienna/wien/r...

# %%
file_path = Path("Data/three-stars-michelin-restaurants.csv")
three_star_data = pd.read_csv(file_path, index_col= 'year')
three_star_data.head()
# Out:
#                name  latitude  longitude                 city      region  \
# year
# 2019         Amador  48.25406   16.35915                 Wien     Austria
# 2019        Manresa  37.22761 -121.98071  South San Francisco  California
# 2019           Benu  37.78521 -122.39876        San Francisco  California
# 2019         Quince  37.79762 -122.40337        San Francisco  California
# 2019  Atelier Crenn  37.79835 -122.43586        San Francisco  California
#
#      zipCode       cuisine  price  \
# year
# 2019    1190      Creative    5.0
# 2019   95030  Contemporary    4.0
# 2019   94105         Asian    4.0
# 2019   94133  Contemporary    4.0
# 2019   94123  Contemporary    4.0
#
#                                                     url
# year
# 2019  https://guide.michelin.com/at/en/vienna/wien/r...
# 2019  https://guide.michelin.com/us/en/california/so...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa
# %%
nyc_one_df.isnull().sum()
# Out:
# name       0
# zipCode    0
# cuisine    0
# price      0
# dtype: int64

# %% [markdown]
# ### Location Data

# %%
nyc_one_loc = nyc_one_star_data.drop(['cuisine', 'url', 'price', 'region'], axis=1)
nyc_one_loc = nyc_one_loc.set_index('city')
nyc_one_loc.head()
# Out:
#                                name   latitude  longitude zipCode
# city
# New York                  Del Posto  40.743270  -74.00770   10011
# New York  Le Grill de Joël Robuchon  40.742897  -74.00770   10011
# New York                   L'Appart  40.711903  -74.01544   10281
# New York                      Okuda  40.743793  -74.00633   10011
# New York                     Wallsé  40.735380  -74.00814   10014

# %%
nyc_one_loc.isnull().sum()
# Out:
# name         0
# latitude     0
# longitude    0
# zipCode      0
# dtype: int64

# %% [markdown]
# ## NYC Two Star Information

# %%
nyc_two_star_data = two_star_data.loc[two_star_data['city'] == 'New York']
nyc_two_star_data.head()
# Out:
#                             name   latitude  longitude      city  \
# year
# 2019  L'Atelier de Joël Robuchon  40.742905  -74.00769  New York
# 2019                     Jungsik  40.718685  -74.00911  New York
# 2019                       Atera  40.716797  -74.00565  New York
# 2019                Jean-Georges  40.769070  -73.98155  New York
# 2019                       Marea  40.767490  -73.98114  New York
#
#              region zipCode       cuisine  price  \
# year
# 2019  New York City   10011        French    4.0
# 2019  New York City   10013        Korean    4.0
# 2019  New York City   10013  Contemporary    4.0
# 2019  New York City   10023  Contemporary    4.0
# 2019  New York City   10019       Seafood    4.0
#
#                                                     url
# year
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...

# %%
nyc_two_df = nyc_two_star_data.drop(['latitude', 'longitude', 'url', 'region'], axis=1)
nyc_two_df = nyc_two_df.set_index('city')
nyc_two_df
# Out:
#                                 name zipCode       cuisine  price
# city
# New York  L'Atelier de Joël Robuchon   10011        French    4.0
# New York                     Jungsik   10013        Korean    4.0
# New York                       Atera   10013  Contemporary    4.0
# New York                Jean-Georges   10023  Contemporary    4.0
# New York                       Marea   10019       Seafood    4.0
# New York            Gabriel Kreuther   10036  Contemporary    4.0
# New York            Ichimura at Uchū   10002      Japanese    4.0
# New York         Sushi Ginza Onodera   10017      Japanese    4.0
# New York                          Ko   10003  Contemporary    4.0
# New York                  The Modern   10019  Contemporary    4.0
# New York                     Aquavit   10022  Scandinavian    4.0
# New York                      Daniel   10065        French    4.0
# New York                        Aska   11249  Scandinavian    4.0
# New York                      Blanca   11206  Contemporary    4.0

# %%
#Convert price/zipCode to int
nyc_two_df['price'] = nyc_two_df['price'].astype(int)
nyc_two_df['zipCode'] = nyc_two_df['zipCode'].astype(int)
nyc_two_df
# Out:
#                                 name  zipCode       cuisine  price
# city
# New York  L'Atelier de Joël Robuchon    10011        French      4
# New York                     Jungsik    10013        Korean      4
# New York                       Atera    10013  Contemporary      4
# New York                Jean-Georges    10023  Contemporary      4
# New York                       Marea    10019       Seafood      4
# New York            Gabriel Kreuther    10036  Contemporary      4
# New York            Ichimura at Uchū    10002      Japanese      4
# New York         Sushi Ginza Onodera    10017      Japanese      4
# New York                          Ko    10003  Contemporary      4
# New York                  The Modern    10019  Contemporary      4
# New York                     Aquavit    10022  Scandinavian      4
# New York                      Daniel    10065        French      4
# New York                        Aska    11249  Scandinavian      4
# New York                      Blanca    11206  Contemporary      4

# %% [markdown]
# ### Location Data

# %%
nyc_two_loc = nyc_two_star_data.drop(['cuisine', 'url', 'price', 'region'], axis=1)
nyc_two_loc = nyc_two_loc.set_index('city')
nyc_two_loc.head()
# Out:
#                                 name   latitude  longitude zipCode
# city
# New York  L'Atelier de Joël Robuchon  40.742905  -74.00769   10011
# New York                     Jungsik  40.718685  -74.00911   10013
# New York                       Atera  40.716797  -74.00565   10013
# New York                Jean-Georges  40.769070  -73.98155   10023
# New York                       Marea  40.767490  -73.98114   10019

# %%
nyc_two_loc.isnull().sum()
# Out:
# name         0
# latitude     0
# longitude    0
# zipCode      0
# dtype: int64

# %% [markdown]
# ## NYC Three Star Information

# %%
nyc_three_star_data = three_star_data.loc[three_star_data['city'] == 'New York']
nyc_three_star_data.head()
# Out:
#                                name  latitude  longitude      city  \
# year
# 2019                           Masa  40.76855  -73.98335  New York
# 2019                         Per Se  40.76828  -73.98292  New York
# 2019                   Le Bernardin  40.76177  -73.98223  New York
# 2019            Eleven Madison Park  40.74170  -73.98712  New York
# 2019  Chef's Table at Brooklyn Fare  40.68872  -73.98581  New York
#
#              region zipCode       cuisine  price  \
# year
# 2019  New York City   10019      Japanese    4.0
# 2019  New York City   10019  Contemporary    4.0
# 2019  New York City   10019       Seafood    4.0
# 2019  New York City   10010  Contemporary    4.0
# 2019  New York City   10018  Contemporary    4.0
#
#                                                     url
# year
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...
# 2019  https://guide.michelin.com/us/en/new-york-stat...

# %%
nyc_three_df = nyc_three_star_data.drop(['latitude', 'longitude', 'url', 'region'], axis=1)
nyc_three_df = nyc_three_df.set_index('city')
nyc_three_df.head()
# Out:
#                                    name zipCode       cuisine  price
# city
# New York                           Masa   10019      Japanese    4.0
# New York                         Per Se   10019  Contemporary    4.0
# New York                   Le Bernardin   10019       Seafood    4.0
# New York            Eleven Madison Park   10010  Contemporary    4.0
# New York  Chef's Table at Brooklyn Fare   10018  Contemporary    4.0

# %% [markdown]
# ### Location Data

# %%
#Convert price/zipCode to int
nyc_three_df['price'] = nyc_three_df['price'].astype(int)
nyc_three_df['zipCode'] = nyc_three_df['zipCode'].astype(int)
nyc_three_df
# Out:
#                                    name  zipCode       cuisine  price
# city
# New York                           Masa    10019      Japanese      4
# New York                         Per Se    10019  Contemporary      4
# New York                   Le Bernardin    10019       Seafood      4
# New York            Eleven Madison Park    10010  Contemporary      4
# New York  Chef's Table at Brooklyn Fare    10018  Contemporary      4

# %%
nyc_three_loc = nyc_three_star_data.drop(['cuisine', 'url', 'price', 'zipCode', 'region'], axis=1)
nyc_three_loc = nyc_three_loc.set_index('city')
nyc_three_loc.head()
# Out:
#                                    name  latitude  longitude
# city
# New York                           Masa  40.76855  -73.98335
# New York                         Per Se  40.76828  -73.98292
# New York                   Le Bernardin  40.76177  -73.98223
# New York            Eleven Madison Park  40.74170  -73.98712
# New York  Chef's Table at Brooklyn Fare  40.68872  -73.98581

# %% [markdown]
# ## SF One Star Information

# San Francisco                    La Toque    94573   Contemporary      4
# San Francisco                     Bouchon    94599         French      3
# San Francisco           Auberge du Soleil    94573    Californian      4
# San Francisco  Farmhouse Inn & Restaurant    95436    Californian      4
# San Francisco               Madrona Manor    95448   Contemporary      4
# San Francisco                Harbor House    95432    Californian      4

# %% [markdown]
# ### Location Data

# %%
sf_one_loc = sf_one_star_data.drop(['cuisine', 'url', 'price', 'region'], axis=1)
sf_one_loc = sf_one_loc.set_index('city')
sf_one_loc.head()
# Out:
#                           name   latitude   longitude zipCode
# city
# San Francisco           Madera  37.420140 -122.211510   94025
# San Francisco  The Village Pub  37.428970 -122.251780   94062
# San Francisco         Wakuriya  37.521140 -122.336600   94402
# San Francisco  Sushi Yoshizumi  37.565075 -122.321100   94401
# San Francisco             Rasa  37.577522 -122.345985   94010

# %% [markdown]
# ## SF Two Star Information

# %%
sf_two_star_data = two_star_data.loc[two_star_data['city'] == 'San Francisco']
sf_two_star_data.head()
# Out:
#                name   latitude   longitude           city      region zipCode  \
# year
# 2019         Commis  37.824760 -122.255050  San Francisco  California   94601
# 2019    Californios  37.755550 -122.417145  San Francisco  California   94110
# 2019      Lazy Bear  37.760204 -122.419690  San Francisco  California   94110
# 2019         Saison  37.763270 -122.415430  San Francisco  California   94107
# 2019  Campton Place  37.789230 -122.406650  San Francisco  California   94108
#
#            cuisine  price                                                url
# year
# 2019  Contemporary    4.0  https://guide.michelin.com/us/en/california/sa...
# 2019       Mexican    4.0  https://guide.michelin.com/us/en/california/sa...
# 2019  Contemporary    4.0  https://guide.michelin.com/us/en/california/sa...
# 2019   Californian    4.0  https://guide.michelin.com/us/en/california/sa...
# 2019        Indian    4.0  https://guide.michelin.com/us/en/california/sa...

# %%
sf_two_df = sf_two_star_data.drop(['latitude', 'longitude', 'url', 'region'], axis=1)
sf_two_df = sf_two_df.set_index('city')
sf_two_df.head()
# Out:
#                         name zipCode       cuisine  price
# city
# San Francisco         Commis   94601  Contemporary    4.0
# San Francisco    Californios   94110       Mexican    4.0
# San Francisco      Lazy Bear   94110  Contemporary    4.0
# San Francisco         Saison   94107   Californian    4.0
# San Francisco  Campton Place   94108        Indian    4.0

# %%
#Convert price/zipCode to int
sf_two_df['price'] = sf_two_df['price'].astype(int)
sf_two_df['zipCode'] = sf_two_df['zipCode'].astype(int)
sf_two_df
# Out:
#                         name  zipCode       cuisine  price
# city
# San Francisco         Commis    94601  Contemporary      4
# San Francisco    Californios    94110       Mexican      4
# San Francisco      Lazy Bear    94110  Contemporary      4
# San Francisco         Saison    94107   Californian      4
# San Francisco  Campton Place    94108        Indian      4
# San Francisco            Coi    94133  Contemporary      4
# San Francisco     Acquerello    94109       Italian      4

# %% [markdown]
# ### Location Data

# %%
sf_two_loc = sf_two_star_data.drop(['cuisine', 'url', 'price', 'region'], axis=1)
sf_two_loc = sf_two_loc.set_index('city')
sf_two_loc.head()
# Out:
#                         name   latitude   longitude zipCode
# city
# San Francisco         Commis  37.824760 -122.255050   94601
# San Francisco    Californios  37.755550 -122.417145   94110
# San Francisco      Lazy Bear  37.760204 -122.419690   94110
# San Francisco         Saison  37.763270 -122.415430   94107
# San Francisco  Campton Place  37.789230 -122.406650   94108

# %% [markdown]
# ## SF Three Star Information

# %%
sf_three_star_data = three_star_data.loc[three_star_data['city'] == 'San Francisco']
sf_three_star_data.head()
# Out:
#                              name  latitude  longitude           city  \
# year
# 2019                         Benu  37.78521 -122.39876  San Francisco
# 2019                       Quince  37.79762 -122.40337  San Francisco
# 2019                Atelier Crenn  37.79835 -122.43586  San Francisco
# 2019           The French Laundry  38.40443 -122.36474  San Francisco
# 2019  The Restaurant at Meadowood  38.52025 -122.46479  San Francisco
#
#           region zipCode       cuisine  price  \
# year
# 2019  California   94105         Asian    4.0
# 2019  California   94133  Contemporary    4.0
# 2019  California   94123  Contemporary    4.0
# 2019  California   94599  Contemporary    4.0
# 2019  California   94574  Contemporary    4.0
#
#                                                     url
# year
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...
# 2019  https://guide.michelin.com/us/en/california/sa...

# %%
sf_three_df = sf_three_star_data.drop(['latitude', 'longitude', 'url', 'region'], axis=1)
sf_three_df = sf_three_df.set_index('city')
sf_three_df.head()
# Out:
#                                       name zipCode       cuisine  price
# city
# San Francisco                         Benu   94105         Asian    4.0
# San Francisco                       Quince   94133  Contemporary    4.0
# San Francisco                Atelier Crenn   94123  Contemporary    4.0
# San Francisco           The French Laundry   94599  Contemporary    4.0
# San Francisco  The Restaurant at Meadowood   94574  Contemporary    4.0

# %%
#Convert price/zipCode to int
sf_three_df['price'] = sf_three_df['price'].astype(int)
sf_three_df['zipCode'] = sf_three_df['zipCode'].astype(int)
sf_three_df
# Out:
#                                       name  zipCode       cuisine  price
# city
# San Francisco                         Benu    94105         Asian      4
# San Francisco                       Quince    94133  Contemporary      4
# San Francisco                Atelier Crenn    94123  Contemporary      4
# San Francisco           The French Laundry    94599  Contemporary      4
# San Francisco  The Restaurant at Meadowood    94574  Contemporary      4
# San Francisco                 SingleThread    95448  Contemporary      4

# %% [markdown]
# ### Location Data

# %%
sf_three_loc = sf_three_star_data.drop(['cuisine', 'url', 'price', 'region'], axis=1)
sf_three_loc = sf_three_loc.set_index('city')
sf_three_loc.head()
# Out:
#                                       name  latitude  longitude zipCode
# city
# San Francisco                         Benu  37.78521 -122.39876   94105
# San Francisco                       Quince  37.79762 -122.40337   94133
# San Francisco                Atelier Crenn  37.79835 -122.43586   94123
# San Francisco           The French Laundry  38.40443 -122.36474   94599
# San Francisco  The Restaurant at Meadowood  38.52025 -122.46479   94574

# %% [markdown]
# ## 1 Star NY Cuisine

# %%
cuisine_nyc1 = nyc_one_df.groupby('cuisine').count()[['name']]
cuisine_nyc1.rename(columns={"name":'Counts'}, inplace=True)

# %%
cuisine_nyc1.head()
# Out:
#               Counts
# cuisine
# American           4
# Austrian           1
# Chinese            1
# Contemporary       9
# French             4

# %%
# Add percentages
ny_1_cuisine = cuisine_nyc1.plot.pie(y='Counts',autopct='%1.1f%%', figsize=(15,15))

# %% [markdown]
# ## 2 Star NY Cuisine

# %%
cuisine_nyc2 = nyc_two_df.groupby('cuisine').count()[['name']]
cuisine_nyc2.rename(columns={"name":'Counts'}, inplace=True)

# %%
cuisine_nyc2.head()
# Out:
#               Counts
# cuisine
# Contemporary       6
# French             2
# Japanese           2
# Korean             1
# Scandinavian       2

# %%
ny_2_cuisine= cuisine_nyc2.plot.pie(y='Counts',autopct='%1.1f%%', figsize=(10,10))

# %% [markdown]
# ## 3 Star NY Cuisine

# %%
cuisine_nyc3 = nyc_three_df.groupby('cuisine').count()[['name']]
cuisine_nyc3.rename(columns={"name":'Counts'}, inplace=True)

# %%
cuisine_nyc3.head()
# Out:
#               Counts
# cuisine
# Contemporary       3
# Japanese           1
# Seafood            1

# %%
ny_3_cuisine= cuisine_nyc3.plot.pie(y='Counts', autopct='%1.1f%%',figsize=(10,10))

# %% [markdown]
# ## 1 Star San Francisco Cuisine

# %%
cuisine_sf1 = sf_one_df.groupby('cuisine').count()[['name']]
cuisine_sf1.rename(columns={"name":'Counts'}, inplace=True)

# %%
cuisine_sf1.head()
# Out:
#               Counts
# cuisine
# American           2
# Californian       10
# Chinese            1
# Contemporary      13
# French             2

# %%
sf_1_cuisine= cuisine_sf1.plot.pie(y='Counts', autopct='%1.1f%%', figsize=(15,15))

# %% [markdown]
# ## 2 Star San Francisco Cuisine

# %%
cuisine_sf2 = sf_two_df.groupby('cuisine').count()[['name']]
cuisine_sf2.rename(columns={"name":'Counts'}, inplace=True)

# %%
cuisine_sf2.head()
# Out:
#               Counts
# cuisine
# Californian        1
# Contemporary       3
# Indian             1
# Italian            1
# Mexican            1

# %%
help(px.pie)
# Out:
# Help on function pie in module plotly.express._chart_types:
#
# pie(data_frame=None, names=None, values=None, color=None, color_discrete_sequence=None, color_discrete_map=None, hover_name=None, hover_data=None, custom_data=None, labels=None, title=None, template=None, width=None, height=None, opacity=None, hole=None)
#         In a pie plot, each row of `data_frame` is represented as a sector of a
#         pie.
#
#     Parameters
#     ----------
#     data_frame: DataFrame or array-like or dict
#         This argument needs to be passed for column names (and not keyword
#         names) to be used. Array-like and dict are tranformed internally to a
#         pandas DataFrame. Optional: if missing, a DataFrame gets constructed
#         under the hood using the other arguments.
#     names: str or int or Series or array-like
#         Either a name of a column in `data_frame`, or a pandas Series or
#         array_like object. Values from this column or array_like are used as
#         labels for sectors.
#     values: str or int or Series or array-like
#         Either a name of a column in `data_frame`, or a pandas Series or
#         array_like object. Values from this column or array_like are used to
#         set values associated to sectors.
#     color: str or int or Series or array-like
#         Either a name of a column in `data_frame`, or a pandas Series or
#         array_like object. Values from this column or array_like are used to
#         assign color to marks.
#     color_discrete_sequence: list of str
#         Strings should define valid CSS-colors. When `color` is set and the
#         values in the corresponding column are not numeric, values in that
#         column are assigned colors by cycling through `color_discrete_sequence`
#         in the order described in `category_orders`, unless the value of
#         `color` is a key in `color_discrete_map`. Various useful color
#         sequences are available in the `plotly.express.colors` submodules,
#         specifically `plotly.express.colors.qualitative`.
#     color_discrete_map: dict with str keys and str values (default `{}`)
#         String values should define valid CSS-colors Used to override
#         `color_discrete_sequence` to assign a specific colors to marks
#         corresponding with specific values. Keys in `color_discrete_map` should
#         be values in the column denoted by `color`. Alternatively, if the
#         values of `color` are valid colors, the string `'identity'` may be
#         passed to cause them to be used directly.
#     hover_name: str or int or Series or array-like
#         Either a name of a column in `data_frame`, or a pandas Series or
#         array_like object. Values from this column or array_like appear in bold
#         in the hover tooltip.
#     hover_data: list of str or int, or Series or array-like, or dict
#         Either a list of names of columns in `data_frame`, or pandas Series, or
#         array_like objects or a dict with column names as keys, with values
#         True (for default formatting) False (in order to remove this column
#         from hover information), or a formatting string, for example ':.3f' or
#         '|%a' or list-like data to appear in the hover tooltip or tuples with a
#         bool or formatting string as first element, and list-like data to
#         appear in hover as second element Values from these columns appear as
#         extra data in the hover tooltip.
#     custom_data: list of str or int, or Series or array-like
#         Either names of columns in `data_frame`, or pandas Series, or
#         array_like objects Values from these columns are extra data, to be used
#         in widgets or Dash callbacks for example. This data is not user-visible
#         but is included in events emitted by the figure (lasso selection etc.)
#     labels: dict with str keys and str values (default `{}`)
#         By default, column names are used in the figure for axis titles, legend
#         entries and hovers. This parameter allows this to be overridden. The
#         keys of this dict should correspond to column names, and the values
#         should correspond to the desired label to be displayed.
#     title: str
#         The figure title.
#     template: str or dict or plotly.graph_objects.layout.Template instance
#         The figure template name (must be a key in plotly.io.templates) or
#         definition.
#     width: int (default `None`)
#         The figure width in pixels.
#     height: int (default `None`)
#         The figure height in pixels.
#     opacity: float
#         Value between 0 and 1. Sets the opacity for markers.
#     hole: float
#         Sets the fraction of the radius to cut out of the pie.Use this to make
#         a donut chart.
#
#     Returns
#     -------
#         plotly.graph_objects.Figure

# %%
sf_2_cuisine = cuisine_sf1.plot.pie(y='Counts', autopct='%1.1f%%', figsize=(15,15))

# %% [markdown]
# ## 3 Star San Francisco Cuisine

# %%
cuisine_sf3 = sf_three_df.groupby('cuisine').count()[['name']]
cuisine_sf3.rename(columns={"name":'Counts'}, inplace=True)

# %%
cuisine_sf3.head()
# Out:
#               Counts
# cuisine
# Asian              1
# Contemporary       5

# %%
sf_3_cuisine = cuisine_sf3.plot.pie(y='Counts', autopct='%1.1f%%', figsize=(10,10))

# %%
import panel as pn
from panel.interact import interact
from panel import widgets

# %%
star_cuisine_tab = pn.Tabs(
    ("New York 1 Star by Cuisine", ny_1_cuisine),
    ("San Francisco 1 Star by Cuisine", sf_1_cuisine),
    ("New York 2 Star by Cuisine", ny_2_cuisine),
    ("San Francisco 2 Star by Cuisine", sf_2_cuisine),
    ("New York 3 Star by Cuisine", ny_3_cuisine),
    ("San Francisco 3 Star by Cuisine", sf_3_cuisine))

star_cuisine_tab
# Out:
# Tabs
#     [0] Str(AxesSubplot, name='New York 1 Star b...)
#     [1] Str(AxesSubplot, name='San Francisco 1...)
#     [2] Str(AxesSubplot, name='New York 2 Star b...)
#     [3] Str(AxesSubplot, name='San Francisco 2...)
#     [4] Str(AxesSubplot, name='New York 3 Star b...)
#     [5] Str(AxesSubplot, name='San Francisco 3...)

# %%
ny_row = pn.Row(ny_1_cuisine, ny_2_cuisine)
ny_row
# Out:
# Row
#     [0] Str(AxesSubplot)
#     [1] Str(AxesSubplot)
